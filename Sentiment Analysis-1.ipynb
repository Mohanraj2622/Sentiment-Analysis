# %% [markdown]
# step-1

# %%
import pandas as pd

df = pd.read_excel("Age and Experience.xlsx")

# %% [markdown]
# step-2

# %%
print(df.head())

print(df.info())
# Out:
#    Age  Work experience
# 0   35                15
# 1   35                15
# 2   35                15
# 3   35                15
# 4   35                15
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               150 non-null    int64
#  1   Work experience   150 non-null    int64
# dtypes: int64(2)
# memory usage: 2.5 KB
# None

# %% [markdown]
# step-3

# %%
print(df.isnull().sum())
# Out:
# Age                 0
# Work experience     0
# dtype: int64

# %% [markdown]
# step-4

# %%
data = df.drop_duplicates(subset="Age")
print(data)
# Out:
#      Age  Work experience
# 0     35                15
# 5     39                18
# 12    32                18
# 20    33                20
# 21    45                20
# 24    46                20
# 29    49                20
# 33    42                20
# 45    44                20
# 56    47                22
# 60    55                22
# 80    52                24
# 107   57                25
# 130   53                25
# 146   51                31

# %% [markdown]
# step-5

# %%
print(df.describe())
print(df["Age"].value_counts(2))
# data visualisation
# Out:
#               Age  Work experience
# count  150.000000         150.00000
# mean    48.940000          23.08000
# std      7.293677           3.61674
# min     32.000000          15.00000
# 25%     44.000000          20.00000
# 50%     52.000000          24.00000
# 75%     55.000000          25.00000
# max     57.000000          31.00000
# Age
# 52    0.180000
# 57    0.153333
# 55    0.133333
# 53    0.106667
# 42    0.080000
# 44    0.073333
# 32    0.053333
# 39    0.046667
# 35    0.033333
# 46    0.033333
# 49    0.026667
# 47    0.026667
# 51    0.026667
# 45    0.020000
# 33    0.006667
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="Age", data=df)
plt.show()

sns.countplot(y="Age", data=df)
plt.show()
